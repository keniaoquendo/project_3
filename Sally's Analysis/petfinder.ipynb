# %%
# Dependencies
import random
import json
import requests
from pprint import pprint
# from config import api_key

# %%
url = "https://api.petfinder.com/v2/animals"
response = requests.get(url , headers={"Authorization":"Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..FMrM9d93a7NXjX_UNUscHhD0qRKmSnF4A5Oo35OCgKMXV0-0W8NYw1pkR8RU-QyAiE58NES2ZN5E7HW7I7M2W_4PoFxDkn0YHVNhpe27nP9Y6gLoWIDxX2h5j8RDJZQbjbQtpkhYVVgZi3_N0KUV534rHjr7rmtjN5HaWx9y-UYHtvzlUT-MMRRpOlUi1LjhmEUHTOCH1dpnaeApAAN5Z7DmgCVxCh3yjaaZQ7ov9RYtCv0K1t1iV79qaPH1ltoOtW8dXc0Qtf4lgCxWU4WMteNZHt-steeOBkMU04jY3JjxfZdZmF-iZyN3Jbl-Gfz-p-2aoKBz7CRUkEkxf05DWQ"})

# %%
pet_response = response.json()
animals = pet_response['animals']
pprint(animals)
# Out:
# [{'_links': {'organization': {'href': '/v2/organizations/ca2251'},
#              'self': {'href': '/v2/animals/70479095'},
#              'type': {'href': '/v2/types/dog'}},
#   'age': 'Baby',
#   'attributes': {'declawed': None,
#                  'house_trained': False,
#                  'shots_current': False,
#                  'spayed_neutered': False,
#                  'special_needs': False},
#   'breeds': {'mixed': True,
#              'primary': 'Boxer',
#              'secondary': 'Pit Bull Terrier',
#              'unknown': False},
#   'coat': None,
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'contact': {'address': {'address1': None,
#                           'address2': None,
#                           'city': 'San Jose',
#                           'country': 'US',
#                           'postcode': '95155',
#                           'state': 'CA'},
#               'email': 'petfinders@jakeswishrescue.org',
# ...

# %%
len(animals)
# Out:
# 20
