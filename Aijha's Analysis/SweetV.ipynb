# %%
#installing the library
! pip install sweetviz

# %%
#importing dependencies
import pandas as pd

#loading the dataset
animals = pd.read_csv('/Users/aijhasymone/Desktop/ClassFolder/project_3/resources/jan29_states_final.csv')

# %%
# Separating X and Y

X = animals.drop('id', axis=1)
Y = animals['id']

# %%
#displaying data from X
X
# Out:
#       Unnamed: 0 organization_id state                 name type    age  \
# 0              0          TX2305    TX                Davon  Dog  Adult
# 1              1           MO486    MO                 Mack  Dog  Adult
# 2              2           MI812    MI  Lahni! DNA tested!   Dog  Adult
# 3              3           MS214    MS        Jughead Jones  Dog   Baby
# 4              4            AZ57    AZ                 Mona  Dog  Young
# ...          ...             ...   ...                  ...  ...    ...
# 1909        1909           CA912    CA              Turkina  Cat  Young
# 1910        1910           CA912    CA                Wyatt  Dog  Young
# 1911        1911           GA803    GA                Hilda  Dog  Adult
# 1912        1912           WA780    WA                 Erik  Dog  Adult
# 1913        1913           KS283    KS                 Moon  Cat   Baby
#
#       gender         size                                                url
# ...

# %%
#data before split
animals
# Out:
#       Unnamed: 0        id organization_id state                 name type  \
# 0              0  70490327          TX2305    TX                Davon  Dog
# 1              1  70490328           MO486    MO                 Mack  Dog
# 2              2  70490326           MI812    MI  Lahni! DNA tested!   Dog
# 3              3  70490283           MS214    MS        Jughead Jones  Dog
# 4              4  70490324            AZ57    AZ                 Mona  Dog
# ...          ...       ...             ...   ...                  ...  ...
# 1909        1909  70487012           CA912    CA              Turkina  Cat
# 1910        1910  70487015           CA912    CA                Wyatt  Dog
# 1911        1911  70487006           GA803    GA                Hilda  Dog
# 1912        1912  70487003           WA780    WA                 Erik  Dog
# 1913        1913  70487004           KS283    KS                 Moon  Cat
#
#         age  gender         size  \
# ...

# %%
#displaying data from Y
Y
# Out:
# 0       70490327
# 1       70490328
# 2       70490326
# 3       70490283
# 4       70490324
#           ...
# 1909    70487012
# 1910    70487015
# 1911    70487006
# 1912    70487003
# 1913    70487004
# Name: id, Length: 1914, dtype: int64

# %%
#creating a EDA report

import sweetviz as sv
analyze_report = sv.analyze(animals)
analyze_report.show_html('analyze.html', open_browser=True)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report analyze.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
import IPython

IPython.display.HTML('analyze.html')
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
